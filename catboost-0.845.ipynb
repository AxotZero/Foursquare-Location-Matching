# %%
UTIL_PATH = "../input/4sq-catboost-models"
DF_PATH = "../input/foursquare-location-matching/test.csv"
SUB_PATH = "../input/foursquare-location-matching/sample_submission.csv"

# %%
import numpy as np
import pandas as pd

import sys
sys.path.insert(0, UTIL_PATH) 

from fsq_utils import *


from catboost import CatBoostClassifier
from tqdm import tqdm
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# ## Extracting Nearest Neighbors

# %%
df = pd.read_csv(DF_PATH).reset_index()
coo_cols = ["latitude", "longitude"]

num_split = 5
N = 40 if len(df)>30000 else 2

distances, indices = calc_dists_and_indices(df=df,
                                            N=N,
                                            cols=coo_cols)

# %% [markdown]
# ## Extracting Essential Similarities

# %%
text_cols = ["address", "url", "phone", "name"]
V_textcols = textcol_tfidf(df=df,
                            cols=text_cols)

V_cat = cat_tfidf(df=df)

ids, match_ids, candidate_df_ = calc_essential_feats(df=df,
                                                     indices=indices,
                                                     distances=distances,
                                                     textcol_tfidf=V_textcols,
                                                     cat_tfidf=V_cat,
                                                     train_mode=False)
# Out:
# address (5, 51)
# url (5, 19)
# phone (5, 16)
# name (5, 73)
# categories (5, 5)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def pred_w_model(foldnum, df_x):
    model = CatBoostClassifier()
    model.load_model(UTIL_PATH+'/cb_fold_'+str(foldnum))
    pred = model.predict_proba(df_x)[:,1]
    del model
    gc_clear()
    return pred

# %% [markdown]
# ## Extracting Word Similarity Stats
# We are using all cores in here. It affects the execution speed so much! ⚡

# %%
STR_FE_COLS = ['name', 'categories']
PAIR_COLS = ['name', 'categories']

# %% [markdown]
# ## CV Prediction

# %%
split_size = len(candidate_df_) // num_split

matches_list = {}
for i in range(num_split):
    s_idx = split_size * i
    e_idx = split_size * (i+1)
    if i == (num_split - 1):
        candidate_df = extract_features(candidate_df_.iloc[s_idx:], PAIR_COLS)
    else:
        candidate_df = extract_features(candidate_df_.iloc[s_idx:e_idx], PAIR_COLS)
        
    preds = [pred_w_model(i, candidate_df) for i in range(7)] 
    thresholds = np.load(UTIL_PATH+"/fold_threshs.npy")
    candidate_df["pred"] = (
        np.mean(
            [
                (preds[pred_i] >= thresholds[pred_i]).astype(int)
                for pred_i, pred in enumerate(preds)
            ],
            axis=0,
        )
        >= 0.5
    ).astype(int)
    
    candidate_df['ids'] = ids
    candidate_df['match_id'] = match_ids
    pred_match_mask = candidate_df.pred==1
    for ids, groupby_df in candidate_df[pred_match_mask].groupby("ids"):
        if ids not in matches_list:
            matches_list[ids] = []
        matches_list[ids].extend(list(groupby_df.match_id.values))
# Out:
# ../input/4sq-catboost-models/fsq_utils.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["idx_group"] = df.index // (len(df) / 256)
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
preds
# Out:
# [array([0.72300172]),
#  array([0.98024957]),
#  array([0.98234718]),
#  array([0.641768]),
#  array([0.98785984]),
#  array([0.99447513]),
#  array([0.96643192])]

# %% [markdown]
# ## Creating the submission

# %%
subm_df=pd.read_csv(SUB_PATH)
subm_df["matches"] = np.nan

# %%
def set_setter(selected_id):
    try:
        return " ".join(matches_list[selected_id])
    except:
        return ""

subm_df['matches'] = subm_df['id'].progress_apply(lambda x: set_setter(x))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ### Adding the self match

# %%
subm_df['matches'] = subm_df['id'] + " " + subm_df['matches']

# %% [markdown]
# ## The submission

# %%
subm_df
# Out:
#                  id                                            matches
# 0  E_00001118ad0191  E_00001118ad0191 E_001b6bad66eb98 E_001b6bad66...
# 1  E_000020eb6fed40                                  E_000020eb6fed40
# 2  E_00002f98667edf                                  E_00002f98667edf
# 3  E_001b6bad66eb98                                  E_001b6bad66eb98
# 4  E_0283d9f61e569d                                  E_0283d9f61e569d

# %%
subm_df.to_csv("submission.csv", index=False)
